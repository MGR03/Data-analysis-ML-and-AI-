# %%
## 1. importing libraries

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
## 2. Reading data

mydata = pd.read_csv("insurance.csv")
mydata
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
mydata.tail()
# Out:
#       age     sex    bmi  children smoker     region     charges
# 1333   50    male  30.97         3     no  northwest  10600.5483
# 1334   18  female  31.92         0     no  northeast   2205.9808
# 1335   18  female  36.85         0     no  southeast   1629.8335
# 1336   21  female  25.80         0     no  southwest   2007.9450
# 1337   61  female  29.07         0    yes  northwest  29141.3603

# %%
mydata.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
mydata.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %%
# 3b Finding the type of data of each attribute in the data set.

# %%
datatype = mydata.dtypes
print(datatype)
# Out:
# age           int64
# sex          object
# bmi         float64
# children      int64
# smoker       object
# region       object
# charges     float64
# dtype: object

# %%
# 3a DATA Shape

# %%
Shape = mydata.shape
Shape
# Out:
# (1338, 7)

# %%
# 3c Checking null values in the table

# %%
mydata.isnull()
# Out:
#         age    sex    bmi  children  smoker  region  charges
# 0     False  False  False     False   False   False    False
# 1     False  False  False     False   False   False    False
# 2     False  False  False     False   False   False    False
# 3     False  False  False     False   False   False    False
# 4     False  False  False     False   False   False    False
# ...     ...    ...    ...       ...     ...     ...      ...
# 1333  False  False  False     False   False   False    False
# 1334  False  False  False     False   False   False    False
# 1335  False  False  False     False   False   False    False
# 1336  False  False  False     False   False   False    False
# 1337  False  False  False     False   False   False    False
#
# [1338 rows x 7 columns]

# %%
#Number of null values throughout the table.

mydata.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
mydata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
# 3d Point summary

mydata.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %%
# 3e Distribution of bmi, age and charges

sns.displot(mydata['bmi'], kde=True);

# %%
sns.displot(mydata['age'], kde=True );

# %%
sns.displot(mydata['charges'], kde=True );

# %%
mydata.hist(figsize=(20,20));

# %%
## 3f Check for data skewness

# %%
mydata.skew()
# Out:
# age         0.055673
# bmi         0.284047
# children    0.938380
# charges     1.515880
# dtype: float64

# %%
mydata["bmi"].skew(), mydata["age"].skew(), mydata["charges"].skew()
# Out:
# (0.2840471105987448, 0.05567251565299186, 1.5158796580240388)

# %%
# 3g Checking for outliers

# %%
mydata.columns
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'charges'], dtype='object')

# %%
#Overall outliers in BMI column

plt.boxplot(mydata['bmi'],vert=False);

plt.title('BMI Outlier');
plt.xlabel('BMI');

# %%
#BMI outliers within people with zero to five children.

sns.boxplot(data=mydata, y='bmi', x= 'children');

# %%
#BMI outliers within people within sex

sns.boxplot(data=mydata, y='bmi', x= 'sex');

# %%
#Overall outliers in Age column

plt.boxplot(data=mydata, x='age', vert=False);

plt.title('Age Outlier');
plt.xlabel('Age');

# %%
#Age outliers within people with zero to five children.

sns.boxplot(data=mydata, y='age', x= 'children');

# %%
#Age outliers within people with sex

sns.boxplot(data=mydata, y='age', x= 'sex');

# %%
#Overall outliers in Charges column

plt.boxplot(mydata['charges'], vert=False);

plt.title('Charges Outlier');
plt.xlabel('Charges');

# %%
#charges outliers within people within children


sns.boxplot(data=mydata, y='charges', x= 'children');

# %%
#charges outliers within people within sex

sns.boxplot(data=mydata, y='charges', x= 'sex');

# %%
# 3h. Distribution of Categorial column

# %%
mydata.describe(include='all')
# Out:
#                 age   sex          bmi     children smoker     region  \
# count   1338.000000  1338  1338.000000  1338.000000   1338       1338
# unique          NaN     2          NaN          NaN      2          4
# top             NaN  male          NaN          NaN     no  southeast
# freq            NaN   676          NaN          NaN   1064        364
# mean      39.207025   NaN    30.663397     1.094918    NaN        NaN
# std       14.049960   NaN     6.098187     1.205493    NaN        NaN
# min       18.000000   NaN    15.960000     0.000000    NaN        NaN
# 25%       27.000000   NaN    26.296250     0.000000    NaN        NaN
# 50%       39.000000   NaN    30.400000     1.000000    NaN        NaN
# 75%       51.000000   NaN    34.693750     2.000000    NaN        NaN
# max       64.000000   NaN    53.130000     5.000000    NaN        NaN
#
#              charges
# count    1338.000000
# unique           NaN
# top              NaN
# freq             NaN
# ...

# %%
# 3i Pairplot all the columns of dataframe

# %%
sns.pairplot(mydata);

# %%
mydata.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
#4a Do charges of people who smoke differ significantly from the people who don't? - Yes charges of people who are non smokers is lower than smokers.

sns.violinplot(x='smoker',y='charges',data=mydata[['smoker', 'charges']]);

# %%
SmokerMedian= mydata[mydata.smoker == 'yes'][['charges']].median()
NonsmokerMedian= mydata[mydata.smoker == 'no'][['charges']].median()
print('Median of Smoker', SmokerMedian)
print('Median of Non-Smoker', NonsmokerMedian)
# Out:
# Median of Smoker charges    34456.34845
# dtype: float64
# Median of Non-Smoker charges    7345.4053
# dtype: float64

# %%
SmokerMedianM= mydata[mydata.smoker == 'yes'][['charges']].mean()
NonsmokerMedianM= mydata[mydata.smoker == 'no'][['charges']].mean()
print('Mean of Smoker', SmokerMedianM)
print('Mean of Non-Smoker', NonsmokerMedianM)
# Out:
# Mean of Smoker charges    32050.231832
# dtype: float64
# Mean of Non-Smoker charges    8434.268298
# dtype: float64

# %%
#4b Does bmi of males differ significantly from that of females? - Not significantly.

sns.violinplot(x='sex',y='bmi',data=mydata[['sex', 'bmi']]);

# %%
BMImale=mydata[mydata.sex == 'male'][['bmi']].median()
BMIfemale= mydata[mydata.sex == 'female'][['bmi']].median()
print('Median of Male', BMImale)
print ('Median of Female', BMIfemale)
# Out:
# Median of Male bmi    30.6875
# dtype: float64
# Median of Female bmi    30.1075
# dtype: float64

# %%
BMImaleM=mydata[mydata.sex == 'male'][['bmi']].mean()
BMIfemaleM= mydata[mydata.sex == 'female'][['bmi']].mean()
print('Mean of Male', BMImaleM)
print ('Mean of Female', BMIfemaleM)
# Out:
# Mean of Male bmi    30.943129
# dtype: float64
# Mean of Female bmi    30.377749
# dtype: float64

# %%
#4c Is the proportion of smokers significantly different in different genders? - It is different, but not significantly.

sns.countplot(data=mydata, x='smoker', hue='sex');

# %%
Smokers = mydata[mydata.smoker == 'yes']
Only_Smoker = Smokers[['smoker','sex']]
Only_Smoker
# Out:
#      smoker     sex
# 0       yes  female
# 11      yes  female
# 14      yes    male
# 19      yes    male
# 23      yes  female
# ...     ...     ...
# 1313    yes  female
# 1314    yes  female
# 1321    yes    male
# 1323    yes  female
# 1337    yes  female
#
# [274 rows x 2 columns]

# %%
FemaleSmoker = Only_Smoker[Only_Smoker.sex == 'female']
MaleSmoker =Only_Smoker[Only_Smoker.sex == 'male']
FemaleSmoker, MaleSmoker
# Out:
# (     smoker     sex
#  0       yes  female
#  11      yes  female
#  23      yes  female
#  58      yes  female
#  64      yes  female
#  ...     ...     ...
#  1308    yes  female
#  1313    yes  female
#  1314    yes  female
#  1323    yes  female
#  1337    yes  female
#
#  [115 rows x 2 columns],
#       smoker   sex
#  14      yes  male
#  19      yes  male
#  29      yes  male
#  30      yes  male
#  34      yes  male
#  ...     ...   ...
#  1301    yes  male
#  1303    yes  male
#  1304    yes  male
#  1307    yes  male
#  1321    yes  male
#
#  [159 rows x 2 columns])

# %%
Total_Smoker = mydata[mydata.smoker == 'yes']["smoker"].count()
Total_Smoker
# Out:
# 274

# %%
RatioFemale = FemaleSmoker["sex"].count()/Total_Smoker
RatioMale = MaleSmoker["sex"].count()/Total_Smoker
RatioFemale, RatioMale
# Out:
# (0.4197080291970803, 0.5802919708029197)

# %%
mydata.tail()
# Out:
#       age     sex    bmi  children smoker     region     charges
# 1333   50    male  30.97         3     no  northwest  10600.5483
# 1334   18  female  31.92         0     no  northeast   2205.9808
# 1335   18  female  36.85         0     no  southeast   1629.8335
# 1336   21  female  25.80         0     no  southwest   2007.9450
# 1337   61  female  29.07         0    yes  northwest  29141.3603

# %%
# 4d. Distribution of bmi across women with no children, one child and two children, the same

sns.catplot (data=mydata, y='bmi', x='sex', hue='children', dodge=True, kind='strip');

# %%
#Keeping only woman with kids

newdata = mydata.drop(mydata["sex"].loc[mydata["sex"]=='male'].index);

newdata
# Out:
#       age     sex    bmi  children smoker     region      charges
# 0      19  female  27.90         0    yes  southwest  16884.92400
# 5      31  female  25.74         0     no  southeast   3756.62160
# 6      46  female  33.44         1     no  southeast   8240.58960
# 7      37  female  27.74         3     no  northwest   7281.50560
# 9      60  female  25.84         0     no  northwest  28923.13692
# ...   ...     ...    ...       ...    ...        ...          ...
# 1332   52  female  44.70         3     no  southwest  11411.68500
# 1334   18  female  31.92         0     no  northeast   2205.98080
# 1335   18  female  36.85         0     no  southeast   1629.83350
# 1336   21  female  25.80         0     no  southwest   2007.94500
# 1337   61  female  29.07         0    yes  northwest  29141.36030
#
# [662 rows x 7 columns]

# %%
newdata3 = newdata.drop(newdata["children"].loc[newdata["children"]==3].index);

newdata3
# Out:
#       age     sex    bmi  children smoker     region      charges
# 0      19  female  27.90         0    yes  southwest  16884.92400
# 5      31  female  25.74         0     no  southeast   3756.62160
# 6      46  female  33.44         1     no  southeast   8240.58960
# 9      60  female  25.84         0     no  northwest  28923.13692
# 11     62  female  26.29         0    yes  southeast  27808.72510
# ...   ...     ...    ...       ...    ...        ...          ...
# 1331   23  female  33.40         0     no  southwest  10795.93733
# 1334   18  female  31.92         0     no  northeast   2205.98080
# 1335   18  female  36.85         0     no  southeast   1629.83350
# 1336   21  female  25.80         0     no  southwest   2007.94500
# 1337   61  female  29.07         0    yes  northwest  29141.36030
#
# [585 rows x 7 columns]

# %%
newdata4 = newdata3.drop(newdata3["children"].loc[newdata3["children"]==4].index);

newdata4
# Out:
#       age     sex    bmi  children smoker     region      charges
# 0      19  female  27.90         0    yes  southwest  16884.92400
# 5      31  female  25.74         0     no  southeast   3756.62160
# 6      46  female  33.44         1     no  southeast   8240.58960
# 9      60  female  25.84         0     no  northwest  28923.13692
# 11     62  female  26.29         0    yes  southeast  27808.72510
# ...   ...     ...    ...       ...    ...        ...          ...
# 1331   23  female  33.40         0     no  southwest  10795.93733
# 1334   18  female  31.92         0     no  northeast   2205.98080
# 1335   18  female  36.85         0     no  southeast   1629.83350
# 1336   21  female  25.80         0     no  southwest   2007.94500
# 1337   61  female  29.07         0    yes  northwest  29141.36030
#
# [574 rows x 7 columns]

# %%
newdata5 = newdata4.drop(newdata4["children"].loc[newdata4["children"]==5].index);

newdata5
# Out:
#       age     sex    bmi  children smoker     region      charges
# 0      19  female  27.90         0    yes  southwest  16884.92400
# 5      31  female  25.74         0     no  southeast   3756.62160
# 6      46  female  33.44         1     no  southeast   8240.58960
# 9      60  female  25.84         0     no  northwest  28923.13692
# 11     62  female  26.29         0    yes  southeast  27808.72510
# ...   ...     ...    ...       ...    ...        ...          ...
# 1331   23  female  33.40         0     no  southwest  10795.93733
# 1334   18  female  31.92         0     no  northeast   2205.98080
# 1335   18  female  36.85         0     no  southeast   1629.83350
# 1336   21  female  25.80         0     no  southwest   2007.94500
# 1337   61  female  29.07         0    yes  northwest  29141.36030
#
# [566 rows x 7 columns]

# %%
## Distribution of bmi across women with no children, one child and two children

sns.catplot (data=newdata5, y='bmi', x='children', kind='strip');

plt.title('Ditribution of BMI across women with no children, one child and two children');
plt.xlabel('Number of Children');
plt.ylabel('BMI');

# %%
sns.swarmplot(data=newdata5, x='children', y='bmi');
plt.title('Ditribution of BMI across women with no children, one child and two children');
plt.xlabel('Number of Children');
plt.ylabel('BMI');
