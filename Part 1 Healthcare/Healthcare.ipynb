# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from scipy.stats import zscore
import seaborn as sns
import matplotlib.pyplot as plt

# %%
Data = pd.read_csv("Part1 - Normal.csv")
Data
# Out:
#     P_incidence     P_tilt    L_angle    S_slope    P_radius  S_Degree   Class
# 0     38.505273  16.964297  35.112814  21.540976  127.632875  7.986683  Normal
# 1     54.920858  18.968430  51.601455  35.952428  125.846646  2.001642  Normal
# 2     44.362490   8.945435  46.902096  35.417055  129.220682  4.994195  Normal
# 3     48.318931  17.452121  48.000000  30.866809  128.980308 -0.910941  Normal
# 4     45.701789  10.659859  42.577846  35.041929  130.178314 -3.388910  Normal
# ..          ...        ...        ...        ...         ...       ...     ...
# 95    47.903565  13.616688  36.000000  34.286877  117.449062 -4.245395  Normal
# 96    53.936748  20.721496  29.220534  33.215251  114.365845 -0.421010  Normal
# 97    61.446597  22.694968  46.170347  38.751628  125.670725 -2.707880  Normal
# 98    45.252792   8.693157  41.583126  36.559635  118.545842  0.214750  Normal
# 99    33.841641   5.073991  36.641233  28.767649  123.945244 -0.199249  Normal
#
# [100 rows x 7 columns]

# %%
Data.describe()
# Out:
#        P_incidence      P_tilt     L_angle     S_slope    P_radius    S_Degree
# count   100.000000  100.000000  100.000000  100.000000  100.000000  100.000000
# mean     51.685244   12.821414   43.542605   38.863830  123.890834    2.186572
# std      12.368161    6.778503   12.361388    9.624004    9.014246    6.307483
# min      30.741938   -5.845994   19.071075   17.386972  100.501192  -11.058179
# 25%      42.817849    8.799951   35.000000   32.340487  118.182659   -1.511360
# 50%      50.123115   13.482435   42.638923   37.059694  123.874328    1.152710
# 75%      61.470097   16.785953   51.602346   44.608788  129.040401    4.968807
# max      89.834676   29.894119   90.563461   67.195460  147.894637   31.172767

# %%
Data.dtypes
# Out:
# P_incidence    float64
# P_tilt         float64
# L_angle        float64
# S_slope        float64
# P_radius       float64
# S_Degree       float64
# Class           object
# dtype: object

# %%
Data.shape
# Out:
# (100, 7)

# %%
---------------------------------

# %%
Data1 = pd.read_csv("Part1 - Type_H.csv")
Data1.head()
# Out:
#    P_incidence     P_tilt    L_angle    S_slope    P_radius   S_Degree   Class
# 0    63.027818  22.552586  39.609117  40.475232   98.672917  -0.254400  Type_H
# 1    39.056951  10.060991  25.015378  28.995960  114.405425   4.564259  Type_H
# 2    68.832021  22.218482  50.092194  46.613539  105.985135  -3.530317  Type_H
# 3    69.297008  24.652878  44.311238  44.644130  101.868495  11.211523  Type_H
# 4    49.712859   9.652075  28.317406  40.060784  108.168725   7.918501  Type_H

# %%
Data1.describe()
# Out:
#        P_incidence     P_tilt    L_angle    S_slope    P_radius   S_Degree
# count    60.000000  60.000000  60.000000  60.000000   60.000000  60.000000
# mean     47.638407  17.398795  35.463524  30.239612  116.474968   2.480251
# std      10.697131   7.016708   9.767795   7.555388    9.355720   5.531177
# min      26.147921   3.144669  14.000000  13.366931   84.241415 -10.675871
# 25%      41.018099  12.874329  29.038069  25.215275  112.280320  -0.910819
# 50%      46.416169  16.949285  35.164873  30.000659  116.696146   2.542441
# 75%      53.922329  22.002980  42.011563  34.962103  122.042999   6.059666
# max      74.433593  41.557331  62.275275  46.613539  137.540613  15.779697

# %%
Data1.dtypes
# Out:
# P_incidence    float64
# P_tilt         float64
# L_angle        float64
# S_slope        float64
# P_radius       float64
# S_Degree       float64
# Class           object
# dtype: object

# %%
Data1.shape
# Out:
# (60, 7)

# %%
---------------------------------

# %%
Data2=pd.read_csv("Part1 - Type_S.csv")
Data2
# Out:
#      P_incidence     P_tilt    L_angle    S_slope    P_radius    S_Degree  \
# 0      74.377678  32.053104  78.772013  42.324573  143.560690   56.125906
# 1      89.680567  32.704435  83.130732  56.976132  129.955476   92.027277
# 2      44.529051   9.433234  52.000000  35.095817  134.711772   29.106575
# 3      77.690577  21.380645  64.429442  56.309932  114.818751   26.931841
# 4      76.147212  21.936186  82.961502  54.211027  123.932010   10.431972
# ..           ...        ...        ...        ...         ...         ...
# 145    80.111572  33.942432  85.101608  46.169139  125.593624  100.292107
# 146    95.480229  46.550053  59.000000  48.930176   96.683903   77.283072
# 147    74.094731  18.823727  76.032156  55.271004  128.405731   73.388216
# 148    87.679087  20.365613  93.822416  67.313473  120.944829   76.730629
# 149    48.259920  16.417462  36.329137  31.842457   94.882336   28.343799
#
#       Class
# 0    Type_S
# 1    Type_S
# 2    Type_S
# 3    Type_S
# ...

# %%
Data2.describe()
# Out:
#        P_incidence      P_tilt     L_angle     S_slope    P_radius    S_Degree
# count   150.000000  150.000000  150.000000  150.000000  150.000000  150.000000
# mean     71.514224   20.748038   64.110108   50.766186  114.518810   51.896687
# std      15.109337   11.506169   16.397068   12.318813   15.579995   40.108030
# min      37.903910   -6.554948   24.710274   19.290046   70.082575    1.010041
# 25%      60.658136   13.461149   52.000000   43.166815  104.706761   30.393271
# 50%      72.149306   19.309548   62.555200   50.751695  114.842400   42.372509
# 75%      81.075893   29.229680   76.990924   56.675435  123.337307   61.894425
# max     129.834041   49.431864  125.742385  121.429566  163.071041  418.543082

# %%
Data2.dtypes
# Out:
# P_incidence    float64
# P_tilt         float64
# L_angle        float64
# S_slope        float64
# P_radius       float64
# S_Degree       float64
# Class           object
# dtype: object

# %%
Data2.shape
# Out:
# (150, 7)

# %%
DataplusData1 = Data.append(Data1)
DataplusData1
# Out:
#     P_incidence     P_tilt    L_angle    S_slope    P_radius  S_Degree   Class
# 0     38.505273  16.964297  35.112814  21.540976  127.632875  7.986683  Normal
# 1     54.920858  18.968430  51.601455  35.952428  125.846646  2.001642  Normal
# 2     44.362490   8.945435  46.902096  35.417055  129.220682  4.994195  Normal
# 3     48.318931  17.452121  48.000000  30.866809  128.980308 -0.910941  Normal
# 4     45.701789  10.659859  42.577846  35.041929  130.178314 -3.388910  Normal
# ..          ...        ...        ...        ...         ...       ...     ...
# 55    47.657730  13.277385  36.679985  34.380345   98.249781  6.273012  Type_H
# 56    43.349606   7.467469  28.065483  35.882137  112.776187  5.753277  Type_H
# 57    46.855781  15.351514  38.000000  31.504267  116.250917  1.662706  Type_H
# 58    43.203185  19.663146  35.000000  23.540039  124.846109 -2.919076  Type_H
# 59    48.109236  14.930725  35.564683  33.178512  124.056452  7.947905  Type_H
#
# [160 rows x 7 columns]

# %%
DataplusData1.count()
# Out:
# P_incidence    160
# P_tilt         160
# L_angle        160
# S_slope        160
# P_radius       160
# S_Degree       160
# Class          160
# dtype: int64

# %%
DataplusData1.isnull().sum()
# Out:
# P_incidence    0
# P_tilt         0
# L_angle        0
# S_slope        0
# P_radius       0
# S_Degree       0
# Class          0
# dtype: int64

# %%
dataset_comb = DataplusData1.append(Data2)
dataset_comb
# Out:
#      P_incidence     P_tilt    L_angle    S_slope    P_radius    S_Degree  \
# 0      38.505273  16.964297  35.112814  21.540976  127.632875    7.986683
# 1      54.920858  18.968430  51.601455  35.952428  125.846646    2.001642
# 2      44.362490   8.945435  46.902096  35.417055  129.220682    4.994195
# 3      48.318931  17.452121  48.000000  30.866809  128.980308   -0.910941
# 4      45.701789  10.659859  42.577846  35.041929  130.178314   -3.388910
# ..           ...        ...        ...        ...         ...         ...
# 145    80.111572  33.942432  85.101608  46.169139  125.593624  100.292107
# 146    95.480229  46.550053  59.000000  48.930176   96.683903   77.283072
# 147    74.094731  18.823727  76.032156  55.271004  128.405731   73.388216
# 148    87.679087  20.365613  93.822416  67.313473  120.944829   76.730629
# 149    48.259920  16.417462  36.329137  31.842457   94.882336   28.343799
#
#       Class
# 0    Normal
# 1    Normal
# 2    Normal
# 3    Normal
# ...

# %%
dataset_comb.isnull().sum()
# Out:
# P_incidence    0
# P_tilt         0
# L_angle        0
# S_slope        0
# P_radius       0
# S_Degree       0
# Class          0
# dtype: int64

# %%
dataset_comb.describe()
# Out:
#        P_incidence      P_tilt     L_angle     S_slope    P_radius    S_Degree
# count   310.000000  310.000000  310.000000  310.000000  310.000000  310.000000
# mean     60.496653   17.542822   51.930930   42.953831  117.920655   26.296694
# std      17.236520   10.008330   18.554064   13.423102   13.317377   37.559027
# min      26.147921   -6.554948   14.000000   13.366931   70.082575  -11.058179
# 25%      46.430294   10.667069   37.000000   33.347122  110.709196    1.603727
# 50%      58.691038   16.357689   49.562398   42.404912  118.268178   11.767934
# 75%      72.877696   22.120395   63.000000   52.695888  125.467674   41.287352
# max     129.834041   49.431864  125.742385  121.429566  163.071041  418.543082

# %%
dataset_comb.dtypes
# Out:
# P_incidence    float64
# P_tilt         float64
# L_angle        float64
# S_slope        float64
# P_radius       float64
# S_Degree       float64
# Class           object
# dtype: object

# %%
dataset_comb.shape
# Out:
# (310, 7)

# %%
dataset_comb.head()
# Out:
#    P_incidence     P_tilt    L_angle    S_slope    P_radius  S_Degree   Class
# 0    38.505273  16.964297  35.112814  21.540976  127.632875  7.986683  Normal
# 1    54.920858  18.968430  51.601455  35.952428  125.846646  2.001642  Normal
# 2    44.362490   8.945435  46.902096  35.417055  129.220682  4.994195  Normal
# 3    48.318931  17.452121  48.000000  30.866809  128.980308 -0.910941  Normal
# 4    45.701789  10.659859  42.577846  35.041929  130.178314 -3.388910  Normal

# %%
##------------DATA CLEANSING-----------

# %%
dataset_comb.dtypes
# Out:
# P_incidence    float64
# P_tilt         float64
# L_angle        float64
# S_slope        float64
# P_radius       float64
# S_Degree       float64
# Class           object
# dtype: object

# %%
dataset_comb.isnull().sum()
# Out:
# P_incidence    0
# P_tilt         0
# L_angle        0
# S_slope        0
# P_radius       0
# S_Degree       0
# Class          0
# dtype: int64

# %%
##------------DATA ANALYSIS & VISUALISATION-----------

# %%
dataset_comb.describe()
# Out:
#        P_incidence      P_tilt     L_angle     S_slope    P_radius    S_Degree
# count   310.000000  310.000000  310.000000  310.000000  310.000000  310.000000
# mean     60.496653   17.542822   51.930930   42.953831  117.920655   26.296694
# std      17.236520   10.008330   18.554064   13.423102   13.317377   37.559027
# min      26.147921   -6.554948   14.000000   13.366931   70.082575  -11.058179
# 25%      46.430294   10.667069   37.000000   33.347122  110.709196    1.603727
# 50%      58.691038   16.357689   49.562398   42.404912  118.268178   11.767934
# 75%      72.877696   22.120395   63.000000   52.695888  125.467674   41.287352
# max     129.834041   49.431864  125.742385  121.429566  163.071041  418.543082

# %%
sns.pairplot(dataset_comb, diag_kind='kde');

# %%
dataset_comb.corr()
# Out:
#              P_incidence    P_tilt   L_angle   S_slope  P_radius  S_Degree
# P_incidence     1.000000  0.629199  0.717282  0.814960 -0.247467  0.638743
# P_tilt          0.629199  1.000000  0.432764  0.062345  0.032668  0.397862
# L_angle         0.717282  0.432764  1.000000  0.598387 -0.080344  0.533667
# S_slope         0.814960  0.062345  0.598387  1.000000 -0.342128  0.523557
# P_radius       -0.247467  0.032668 -0.080344 -0.342128  1.000000 -0.026065
# S_Degree        0.638743  0.397862  0.533667  0.523557 -0.026065  1.000000

# %%
dataset_comb.hist(figsize=(20,20));

# %%
dataset_comb.skew()
# Out:
# P_incidence    0.520440
# P_tilt         0.676553
# L_angle        0.599451
# S_slope        0.792577
# P_radius      -0.176835
# S_Degree       4.317954
# dtype: float64

# %%
dataset_comb.groupby(["Class"]).count()
# Out:
#         P_incidence  P_tilt  L_angle  S_slope  P_radius  S_Degree
# Class
# Normal           73      73       73       73        73        73
# Nrmal            27      27       27       27        27        27
# Type_H           37      37       37       37        37        37
# Type_S          133     133      133      133       133       133
# tp_s             17      17       17       17        17        17
# type_h           23      23       23       23        23        23

# %%
dataset_comb['Class'] = dataset_comb['Class'].replace({'Nrmal': 'Normal', 'type_h': 'Type_H', 'tp_s': 'Type_S'})

# %%
dataset_comb.groupby(["Class"]).count()
# Out:
#         P_incidence  P_tilt  L_angle  S_slope  P_radius  S_Degree
# Class
# Normal          100     100      100      100       100       100
# Type_H           60      60       60       60        60        60
# Type_S          150     150      150      150       150       150

# %%
sns.countplot(x="Class", data=dataset_comb)
# Out:
# <AxesSubplot:xlabel='Class', ylabel='count'>

# %%
dataset_comb.dtypes
# Out:
# P_incidence    float64
# P_tilt         float64
# L_angle        float64
# S_slope        float64
# P_radius       float64
# S_Degree       float64
# Class           object
# dtype: object

# %%
dataset_comb.Class[dataset_comb.Class == 'Normal'] = 1
dataset_comb.Class[dataset_comb.Class == 'Type_H'] = 2
dataset_comb.Class[dataset_comb.Class == 'Type_S'] = 3
# Out:
# <ipython-input-402-b9debe6bc8b6>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset_comb.Class[dataset_comb.Class == 'Normal'] = 1
# <ipython-input-402-b9debe6bc8b6>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset_comb.Class[dataset_comb.Class == 'Type_H'] = 2
# <ipython-input-402-b9debe6bc8b6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset_comb.Class[dataset_comb.Class == 'Type_S'] = 3

# %%
dataset_comb['Class'] = dataset_comb['Class'].astype(int)

# %%
dataset_comb
# Out:
#      P_incidence     P_tilt    L_angle    S_slope    P_radius    S_Degree  \
# 0      38.505273  16.964297  35.112814  21.540976  127.632875    7.986683
# 1      54.920858  18.968430  51.601455  35.952428  125.846646    2.001642
# 2      44.362490   8.945435  46.902096  35.417055  129.220682    4.994195
# 3      48.318931  17.452121  48.000000  30.866809  128.980308   -0.910941
# 4      45.701789  10.659859  42.577846  35.041929  130.178314   -3.388910
# ..           ...        ...        ...        ...         ...         ...
# 145    80.111572  33.942432  85.101608  46.169139  125.593624  100.292107
# 146    95.480229  46.550053  59.000000  48.930176   96.683903   77.283072
# 147    74.094731  18.823727  76.032156  55.271004  128.405731   73.388216
# 148    87.679087  20.365613  93.822416  67.313473  120.944829   76.730629
# 149    48.259920  16.417462  36.329137  31.842457   94.882336   28.343799
#
#      Class
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
# ...

# %%
dataset_comb.dtypes
# Out:
# P_incidence    float64
# P_tilt         float64
# L_angle        float64
# S_slope        float64
# P_radius       float64
# S_Degree       float64
# Class            int64
# dtype: object

# %%
dataset_comb.groupby(["Class"]).count()
# Out:
#        P_incidence  P_tilt  L_angle  S_slope  P_radius  S_Degree
# Class
# 1              100     100      100      100       100       100
# 2               60      60       60       60        60        60
# 3              150     150      150      150       150       150

# %%
sns.pairplot(data=dataset_comb,hue="Class",palette="Set1")

# %%
plt.figure(figsize=(15,10))
sns.heatmap(dataset_comb.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %%
##------------DATA PRE-PROCESSING-----------

# %%
processdata= dataset_comb
processdata.head()
# Out:
#    P_incidence     P_tilt    L_angle    S_slope    P_radius  S_Degree  Class
# 0    38.505273  16.964297  35.112814  21.540976  127.632875  7.986683      1
# 1    54.920858  18.968430  51.601455  35.952428  125.846646  2.001642      1
# 2    44.362490   8.945435  46.902096  35.417055  129.220682  4.994195      1
# 3    48.318931  17.452121  48.000000  30.866809  128.980308 -0.910941      1
# 4    45.701789  10.659859  42.577846  35.041929  130.178314 -3.388910      1

# %%
processdata.dtypes
# Out:
# P_incidence    float64
# P_tilt         float64
# L_angle        float64
# S_slope        float64
# P_radius       float64
# S_Degree       float64
# Class            int64
# dtype: object

# %%
#Predictor Variables:
X = processdata.drop('Class', axis=1)

#Dependent Variable:
y = processdata['Class']

# %%
#Scaling using Z score

XScaled  = X.apply(zscore)  # convert all attributes to Z scale 

XScaled.describe()
# Out:
#         P_incidence        P_tilt       L_angle       S_slope      P_radius  \
# count  3.100000e+02  3.100000e+02  3.100000e+02  3.100000e+02  3.100000e+02
# mean   8.702716e-17  2.326096e-16  1.980495e-16  5.121351e-17 -6.274551e-16
# std    1.001617e+00  1.001617e+00  1.001617e+00  1.001617e+00  1.001617e+00
# min   -1.996010e+00 -2.411664e+00 -2.047652e+00 -2.207741e+00 -3.597963e+00
# 25%   -8.173982e-01 -6.881138e-01 -8.060267e-01 -7.168418e-01 -5.423830e-01
# 50%   -1.049246e-01 -1.186061e-01 -1.278621e-01 -4.095971e-02  2.613767e-02
# 75%    7.194643e-01  4.581158e-01  5.975493e-01  7.269414e-01  5.676209e-01
# max    4.029206e+00  3.191402e+00  3.984615e+00  5.855771e+00  3.395818e+00
#
#            S_Degree
# count  3.100000e+02
# mean  -8.156558e-17
# std    1.001617e+00
# min   -9.961725e-01
# 25%   -6.585073e-01
# 50%   -3.874502e-01
# 75%    3.997679e-01
# max    1.046035e+01

# %%
X_train, X_test, y_train, y_test = train_test_split(XScaled, y, test_size=0.30, random_state=1)

# %%
##------------Model training, testing and tuning-----------

# %%
NNH = KNeighborsClassifier(n_neighbors= 5 , weights = 'distance' )

# %%
NNH.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(weights='distance')

# %%
predicted_labels = NNH.predict(X_test)
NNH.score(X_test, y_test)
# Out:
# 0.7526881720430108

# %%
#Checking value of K

# %%
scores =[]
for k in range(1,50):
    NNH = KNeighborsClassifier(n_neighbors = k, weights = 'distance' )
    NNH.fit(X_train, y_train)
    scores.append(NNH.score(X_test, y_test))

# %%
plt.plot(range(1,50),scores)

# %%
NNH = KNeighborsClassifier(n_neighbors= 20 , weights = 'distance' )

# %%
NNH.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=20, weights='distance')

# %%
predicted_labels = NNH.predict(X_test)
NNH.score(X_test, y_test)
# Out:
# 0.7956989247311828

# %%
##------------Conclusion and improvisation:-----------
